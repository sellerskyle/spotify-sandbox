# %% [markdown]
# Spotify doesn't provide an API call to get a user's queue, so we do some creative stuff to get the user's queue, sort it, then add it back. There may be some latency.
#
# Queue can be sorted by any of Spotify's exposed metric, found [here](https://developer.spotify.com/documentation/web-api/reference/#objects-index) in the audio features object

# %% [markdown]
# Note: Using this a lot will mess up your spotify metrics, as it technically plays all the songs in your queue everytime you run it

# %%
import base64
import datetime
from urllib.parse import urlencode

import requests
import json

#Follows Spotify's "Implicit Grant" Authorization flow
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    authorization_url = "https://accounts.spotify.com/authorize"
    
    #external functions ("public")
    

    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')

    def get_playlist(self, _id):
        return self.get_resource(_id, resource_type='playlists')

    def get_playlist_tracks(self, _id):
        return self.get_resource(_id, resource_type='playlists', addendum='tracks')

    def get_track_features(self, _id):
        return self.get_resource(_id, resource_type='audio-features')

    def get_track_analysis(self, _id):
      return self.get_resource(_id, resource_type='audio-analysis') 

    def search(self, query=None, operator=None, operator_query=None, search_type='artist', limit=20 ):
        if query == None:
            raise Exception("A query is required")
        if isinstance(query, dict):
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == "or" or operator.lower() == "not":
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f"{query} {operator} {operator_query}"
        query_params = urlencode({"q": query, "type": search_type.lower(), "limit": str(limit)})
        return self.base_search(query_params)


    #internal functions ("private")


    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        } 
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client.")
            # return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
        
        
    def get_resource(self, lookup_id, resource_type='albums', version='v1', addendum=''):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}/{addendum}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    
    
    def base_search(self, query_params): # type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_params}"
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):  
            return {}
        return r.json()

    #generic api request, accepts the full endpoint string

    def generic_get(self, endpoint):
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            print(r.status_code)
            return {}
        return r.json()

    def generic_post(self, endpoint):
        headers = self.get_resource_header()
        r = requests.post(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
          print(r.status_code)
          return r.status_code
        return r.status_code
      

    def generic_put(self, endpoint, data={}):
        headers = self.get_resource_header()
        #r = requests.put(endpoint, headers=headers)
        r = requests.put(endpoint, data=json.dumps(data), headers=headers)
        if r.status_code not in range(200, 299):
            print(r.status_code)
            return {}
        # return r.json()

    #new functions for user functions

    def get_current_user(self):
        endpoint = f"https://api.spotify.com/v1/me"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()

    def get_current_user_recently_played(self):
        endpoint = f"https://api.spotify.com/v1/me/player/recently-played"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()

    def get_current_user_top(self, top_type='tracks', time_range='medium_term'):
        #endpoint = f"https://api.spotify.com/v1/me/top/{top_type}?limit=50&time_range{time_range}"
        endpoint = f"https://api.spotify.com/v1/me/top/{top_type}?time_range={time_range}&limit=50"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            print(r.status_code)
            return {}
        return r.json()

    def get_user(self, user):
        endpoint = f"https://api.spotify.com/v1/users/{user}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()

# %%
import webbrowser
import json

import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import time

# %%
client_id = ""
client_secret = ""

spotify =  SpotifyAPI(client_id, client_secret)

# %%
scopes = ['user-read-email', 'user-read-private', 'playlist-read-collaborative', 'playlist-modify-public', 'playlist-read-private', 'playlist-modify-private', 'user-library-read', 'user-top-read', 'user-read-recently-played', 'user-read-currently-playing']
scopes_string = ' '.join(scopes)
authorization_url = "https://accounts.spotify.com/authorize"


params = {
            "client_id": client_id,
            "response_type": "token",
            "redirect_uri": "http://localhost:7777/callback",
            "scope": scopes_string
        }

# %%
r = requests.get(authorization_url, params)
print("Successful if this is 200: " + str(r.status_code))
print("URL to paste in browser: " + str(r.url))
# Out:
# Successful if this is 200: 200
# URL to paste in browser: https://accounts.spotify.com/login?continue=https%3A%2F%2Faccounts.spotify.com%2Fauthorize%3Fscope%3Duser-read-email%2Buser-read-private%2Bplaylist-read-collaborative%2Bplaylist-modify-public%2Bplaylist-read-private%2Bplaylist-modify-private%2Buser-library-read%2Buser-top-read%2Buser-read-recently-played%2Buser-read-currently-playing%26response_type%3Dtoken%26redirect_uri%3Dhttp%253A%252F%252Flocalhost%253A7777%252Fcallback%26client_id%3D5de0c3326eed4e17a4e2b226fc57a68f

# %%
#paste the entire url you are sent to here as a string(in quotes)
response = ''
response_list_raw = response.split('&')

response_list = []
#hard coded extracting token and expires
for item in response_list_raw:
  response_list.append(item.split('='))

response_list

access_token = response_list[0][1]
expires_in = response_list[2][1]
print(access_token)
# Out:
# BQCuULSJ9ihfeU2I0WLOCZkoLROyIBADjLKcn-ENFrhR5wHlVQ6sJwL0DC79ysR1diqTpQbEQ8u64qshHs57_A1kabfsP1obfvXC6_Oue2aylOJMFJ6rdi7gATdrZmYuxqDn2X4qiVMQ_lnbk0FGRzWyAIu9dxekeq1nuzY9MSTEFw5tqDKn2cdu2ejwGufkCvchJrvGXz8k8NOxFGRtvq4DEnSTu0Sx8mtps82Xd3fisbhA7m_GQ9WtenztNyY5lvc

# %%
spotify_user = SpotifyAPI(client_id, client_secret)

spotify_user.access_token = access_token
spotify_user.access_token_expires = datetime.datetime.now() + datetime.timedelta(seconds=3600)
spotify_user.access_token_did_expire = False

# %%
nu = spotify.search("Khalid", search_type='artist')

u = spotify_user.search("Khalid", search_type='artist')

print(spotify.access_token)
print(nu)
print(spotify_user.access_token)
print(u)
# Out:
# BQARhwI-It_WpXHyskvZ-CbXz_YjxytNeG-I4M1EtvGhMNuql8lApK1kj69cxcD5Bbv2L9bWaLfXduTt2is
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Khalid&type=artist&offset=0&limit=20', 'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'}, 'followers': {'href': None, 'total': 14120534}, 'genres': ['pop'], 'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny', 'id': '6LuN9FCkKOj5PcnpouEgny', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb012b37d6dec8872b18524f78', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174012b37d6dec8872b18524f78', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178012b37d6dec8872b18524f78', 'width': 160}], 'name': 'Khalid', 'popularity': 91, 'type': 'artist', 'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7w9NGVft7cOEEa3CGGILZM'}, 'followers': {'href': None, 'total': 3944}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/7w9NGVft7cOEEa3CGGILZM', 'id': '7w9NGVft7cOEEa3CGGILZM', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb961a0afd4d63c852d9fc0b14', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174961a0afd4d63c852d9fc0b14', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178961a0afd4d63c852d9fc0b14', 'width': 160}], 'name': 'Khalid Gad', 'popularity': 26, 'type': 'artist', 'uri': 'spotify:artist:7w9NGVft7cOEEa3CGGILZM'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/28ztjHIXceRRntmTUfnmUX'}, 'followers': {'href': None, 'total': 1239150}, 'genres': ['classic arab pop', 'rai'], 'href': 'https://api.spotify.com/v1/artists/28ztjHIXceRRntmTUfnmUX', 'id': '28ztjHIXceRRntmTUfnmUX', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebb21be564348724f82433d110', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174b21be564348724f82433d110', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178b21be564348724f82433d110', 'width': 160}], 'name': 'Khaled', 'popularity': 64, 'type': 'artist', 'uri': 'spotify:artist:28ztjHIXceRRntmTUfnmUX'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5A3RNyMFzwRaKxL8lUnfGf'}, 'followers': {'href': None, 'total': 2710}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5A3RNyMFzwRaKxL8lUnfGf', 'id': '5A3RNyMFzwRaKxL8lUnfGf', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273f3559afae796849fbc2a7ec7', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02f3559afae796849fbc2a7ec7', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851f3559afae796849fbc2a7ec7', 'width': 64}], 'name': 'Khalid', 'popularity': 20, 'type': 'artist', 'uri': 'spotify:artist:5A3RNyMFzwRaKxL8lUnfGf'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Jzy4kcxChcbcL2Z6QQRUI'}, 'followers': {'href': None, 'total': 17568}, 'genres': ['bachata'], 'href': 'https://api.spotify.com/v1/artists/5Jzy4kcxChcbcL2Z6QQRUI', 'id': '5Jzy4kcxChcbcL2Z6QQRUI', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebd8da06c71fda766b4c21ab33', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174d8da06c71fda766b4c21ab33', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178d8da06c71fda766b4c21ab33', 'width': 160}], 'name': 'DJ Khalid', 'popularity': 50, 'type': 'artist', 'uri': 'spotify:artist:5Jzy4kcxChcbcL2Z6QQRUI'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Fv5XdhNFT137F5C8Vi8xx'}, 'followers': {'href': None, 'total': 1}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5Fv5XdhNFT137F5C8Vi8xx', 'id': '5Fv5XdhNFT137F5C8Vi8xx', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27326d5f5ca389612c1580cf56a', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0226d5f5 ...
# BQCuULSJ9ihfeU2I0WLOCZkoLROyIBADjLKcn-ENFrhR5wHlVQ6sJwL0DC79ysR1diqTpQbEQ8u64qshHs57_A1kabfsP1obfvXC6_Oue2aylOJMFJ6rdi7gATdrZmYuxqDn2X4qiVMQ_lnbk0FGRzWyAIu9dxekeq1nuzY9MSTEFw5tqDKn2cdu2ejwGufkCvchJrvGXz8k8NOxFGRtvq4DEnSTu0Sx8mtps82Xd3fisbhA7m_GQ9WtenztNyY5lvc
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Khalid&type=artist&offset=0&limit=20', 'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'}, 'followers': {'href': None, 'total': 14120534}, 'genres': ['pop'], 'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny', 'id': '6LuN9FCkKOj5PcnpouEgny', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb012b37d6dec8872b18524f78', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174012b37d6dec8872b18524f78', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178012b37d6dec8872b18524f78', 'width': 160}], 'name': 'Khalid', 'popularity': 91, 'type': 'artist', 'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7w9NGVft7cOEEa3CGGILZM'}, 'followers': {'href': None, 'total': 3944}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/7w9NGVft7cOEEa3CGGILZM', 'id': '7w9NGVft7cOEEa3CGGILZM', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb961a0afd4d63c852d9fc0b14', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174961a0afd4d63c852d9fc0b14', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178961a0afd4d63c852d9fc0b14', 'width': 160}], 'name': 'Khalid Gad', 'popularity': 26, 'type': 'artist', 'uri': 'spotify:artist:7w9NGVft7cOEEa3CGGILZM'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/28ztjHIXceRRntmTUfnmUX'}, 'followers': {'href': None, 'total': 1239150}, 'genres': ['classic arab pop', 'rai'], 'href': 'https://api.spotify.com/v1/artists/28ztjHIXceRRntmTUfnmUX', 'id': '28ztjHIXceRRntmTUfnmUX', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebb21be564348724f82433d110', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174b21be564348724f82433d110', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178b21be564348724f82433d110', 'width': 160}], 'name': 'Khaled', 'popularity': 64, 'type': 'artist', 'uri': 'spotify:artist:28ztjHIXceRRntmTUfnmUX'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5A3RNyMFzwRaKxL8lUnfGf'}, 'followers': {'href': None, 'total': 2710}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5A3RNyMFzwRaKxL8lUnfGf', 'id': '5A3RNyMFzwRaKxL8lUnfGf', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273f3559afae796849fbc2a7ec7', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02f3559afae796849fbc2a7ec7', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851f3559afae796849fbc2a7ec7', 'width': 64}], 'name': 'Khalid', 'popularity': 20, 'type': 'artist', 'uri': 'spotify:artist:5A3RNyMFzwRaKxL8lUnfGf'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Jzy4kcxChcbcL2Z6QQRUI'}, 'followers': {'href': None, 'total': 17568}, 'genres': ['bachata'], 'href': 'https://api.spotify.com/v1/artists/5Jzy4kcxChcbcL2Z6QQRUI', 'id': '5Jzy4kcxChcbcL2Z6QQRUI', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebd8da06c71fda766b4c21ab33', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174d8da06c71fda766b4c21ab33', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178d8da06c71fda766b4c21ab33', 'width': 160}], 'name': 'DJ Khalid', 'popularity': 50, 'type': 'artist', 'uri': 'spotify:artist:5Jzy4kcxChcbcL2Z6QQRUI'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Fv5XdhNFT137F5C8Vi8xx'}, 'followers': {'href': None, 'total': 1}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5Fv5XdhNFT137F5C8Vi8xx', 'id': '5Fv5XdhNFT137F5C8Vi8xx', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27326d5f5ca389612c1580cf56a', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0226d5f5 ...

# %% [markdown]
# End Initialization and test. Begin New stuff

# %%
#finding jeopardy theme song ID
res = spotify.search('Jeopardy Theme', search_type='track')
res
# for track in res['items']:
#   print(track['name'] + ' : ' + track['id'])
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Jeopardy+Theme&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54qL6HOA0vyhhnFw5inqXq'},
#        'href': 'https://api.spotify.com/v1/artists/54qL6HOA0vyhhnFw5inqXq',
#        'id': '54qL6HOA0vyhhnFw5inqXq',
#        'name': 'Mount Royal Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:54qL6HOA0vyhhnFw5inqXq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7Dsiyp2rtYtRGPv5SUqf90'},
#      'href': 'https://api.spotify.com/v1/albums/7Dsiyp2rtYtRGPv5SUqf90',
#      'id': '7Dsiyp2rtYtRGPv5SUqf90',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ba1eb4164d05d1f57b3c2119',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ba1eb4164d05d1f57b3c2119',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ba1eb4164d05d1f57b3c2119',
#        'width': 64}],
#      'name': 'Best Instrumental TV Hits v3',
#      'release_date': '2016-08-23',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:7Dsiyp2rtYtRGPv5SUqf90'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54qL6HOA0vyhhnFw5inqXq'},
#       'href': 'https://api.spotify.com/v1/artists/54qL6HOA0vyhhnFw5inqXq',
#       'id': '54qL6HOA0vyhhnFw5inqXq',
#       'name': 'Mount Royal Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:54qL6HOA0vyhhnFw5inqXq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 31947,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBLFP1619983'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7GyGUC8QFMS9NoHJsgNqh1'},
#     'href': 'https://api.spotify.com/v1/tracks/7GyGUC8QFMS9NoHJsgNqh1',
#     'id': '7GyGUC8QFMS9NoHJsgNqh1',
#     'is_local': False,
#     'name': 'Jeopardy (Theme)',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1ee1ffb6b9c7cb7d10598718fecbd7ca668ae7a6?cid=5de0c3326eed4e17a4e2b226fc57a68f',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7GyGUC8QFMS9NoHJsgNqh1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DwBY9OXikIY0yMP5Vh9iq'},
#        'href': 'https://api.spotify.com/v1/artists/6DwBY9OXikIY0yMP5Vh9iq',
#        'id': '6DwBY9OXikIY0yMP5Vh9iq',
#        'name': 'TV Theme Song Maniacs',
#        'type': 'artist',
#        'uri': 'spotify:artist:6DwBY9OXikIY0yMP5Vh9iq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/638oabOcxGe84jF1ll94YC'},
#      'href': 'https://api.spotify.com/v1/albums/638oabOcxGe84jF1ll94YC',
#      'id': '638oabOcxGe84jF1ll94YC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738c07098e53b59de441c9ce98',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028c07098e53b59de441c9ce98',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518c07098e53b59de441c9ce98',
#        'width': 64}],
#      'name': 'Cover Me: With 99 TV Songs',
#      'release_date': '2010-09-28',
#      'release_date_precision': 'day',
#      'total_tracks': 99,
#      'type': 'album',
#      'uri': 'spotify:album:638oabOcxGe84jF1ll94YC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DwBY9OXikIY0yMP5Vh9iq'},
#       'href': 'https://api.spotify.com/v1/artists/6DwBY9OXikIY0yMP5Vh9iq',
#       'id': '6DwBY9OXikIY0yMP5Vh9iq',
#       'name': 'TV Theme Song Maniacs',
#       'type': 'artist',
#       'uri': 'spotify:artist:6DwBY9OXikIY0yMP5Vh9iq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 36000,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAM460703170'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7HiPgTQFj0L2XHrSC97F1W'},
#     'href': 'https://api.spotify.com/v1/tracks/7HiPgTQFj0L2XHrSC97F1W',
#     'id': '7HiPgTQFj0L2XHrSC97F1W',
#     'is_local': False,
#     'name': 'Theme From Jeopardy! - Think Music',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fac4773b38fba59db7299bcd112f9fb957281432?cid=5de0c3326eed4e17a4e2b226fc57a68f',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7HiPgTQFj0L2XHrSC97F1W'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5itJHkE0MNCpDbj3SSwIL8'},
#        'href': 'https://api.spotify.com/v1/artists/5itJHkE0MNCpDbj3SSwIL8',
#        'id': '5itJHkE0MNCpDbj3SSwIL8',
#        'name': 'Toners',
#        'type': 'artist',
#        'uri': 'spotify:artist:5itJHkE0MNCpDbj3SSwIL8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5H3nAoid7D3Gnnc3QoEF0z'},
#      'href': 'https://api.spotify.com/v1/albums/5H3nAoid7D3Gnnc3QoEF0z',
#      'id': '5H3nAoid7D3Gnnc3QoEF0z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a2cbd57c8224639e592246f7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a2cbd57c8224639e592246f7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a2cbd57c8224639e592246f7',
#        'width': 64}],
#      'name': 'Tunes Now: Themes, Vol. 2',
#      'release_date': '2013-05-10',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:5H3nAoid7D3Gnnc3QoEF0z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5itJHkE0MNCpDbj3SSwIL8'},
#       'href': 'https://api.spotify.com/v1/artists/5itJHkE0MNCpDbj3SSwIL8',
#       'id': '5itJHkE0MNCpDbj3SSwIL8',
#       'name': 'Toners',
#       'type': 'artist',
#       'uri': 'spotify:artist:5itJHkE0MNCpDbj3SSwIL8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 2,
#     'duration_ms': 31947,
#     'explicit': False,
#     'external_ids': {'isrc': 'USGN61303755'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3raXh0ZKJ5sW0Rldq2y2lj'},
#     'href': 'https://api.spotify.com/v1/tracks/3raXh0ZKJ5sW0Rldq2y2lj',
#     'id': '3raXh0ZKJ5sW0Rldq2y2lj',
#     'is_local': False,
#     'name': 'Jeopardy Main Tv Show Theme',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1ee1ffb6b9c7cb7d10598718fecbd7ca668ae7a6?cid=5de0c3326eed4e17a4e2b226fc57a68f',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3raXh0ZKJ5sW0Rldq2y2lj'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sOfFTIMocxq5mPB8SFLHn'},
#        'href': 'https://api.spotify.com/v1/artists/0sOfFTIMocxq5mPB8SFLHn',
#        'id': '0sOfFTIMocxq5mPB8SFLHn',
#        'name': 'Piano Project',
#        'type': 'artist',
#        'uri': 'spotify:artist:0sOfFTIMocxq5mPB8SFLHn'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0lO0NSWTuXzbZMFGlzHB8U'},
#      'href': 'https://api.spotify.com/v1/albums/0lO0NSWTuXzbZMFGlzHB8U',
#      'id': '0lO0NSWTuXzbZMFGlzHB8U',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273867a060d17d92a23f139cded',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02867a060d17d92a23f139cded',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851867a060d17d92a23f139cded',
#        'width': 64}],
#      'name': "Television's Greatest Theme Songs on Piano",
#      'release_date': '2019-05-08',
#      'release_date_precision': 'day',
#      'total_tracks': 34,
#      'type': 'album',
#      'uri': 'spotify:album:0lO0NSWTuXzbZMFGlzHB8U'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sOfFTIMocxq5mPB8SFLHn'},
#       'href': 'https://api.spotify.com/v1/artists/0sOfFTIMocxq5mPB8SFLHn',
#       'id': '0sOfFTIMocxq5mPB8SFLHn',
#       'name': 'Piano Project',
#       'type': 'artist',
#       'uri': 'spotify:artist:0sOfFTIMocxq5mPB8SFLHn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 127198,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ22B2096463'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/580gwKoS3Ohw4MK46PtaVM'},
#     'href': 'https://api.spotify.com/v1/tracks/580gwKoS3Ohw4MK46PtaVM',
#     'id': '580gwKoS3Ohw4MK46PtaVM',
#     'is_local': False,
#     'name': 'Think! (From "Jeopardy")',
#     'popularity': 11,
#     'preview_url': 'https://p.scdn.co/mp3-preview/61531c4280872a34b2728d58f24b1020c544df45?cid=5de0c3326eed4e17a4e2b226fc57a68f',
#     'track_number': 22,
#     'type': 'track',
#     'uri': 'spotify:track:580gwKoS3Ohw4MK46PtaVM'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mF1OinWKYYezIeNfhLrd3'},
#        'href': 'https://api.spotify.com/v1/artists/6mF1OinWKYYezIeNfhLrd3',
#        'id': '6mF1OinWKYYezIeNfhLrd3',
#        'name': 'The Questions',
#        'type': 'artist',
#        'uri': 'spotify:artist:6mF1OinWKYYezIeNfhLrd3'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5bdpvQ02Fk1x15PXlmSYN3'},
#      'href': 'https://api.spotify.com/v1/albums/5bdpvQ02Fk1x15PXlmSYN3',
#      'id': '5bdpvQ02Fk1x15PXlmSYN3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e0a8471f436e07d75c97d4cf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e0a8471f436e07d75c97d4cf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e0a8471f436e07d75c97d4cf',
#        'width': 64}],
#      'name': 'T.V. Game Show Themes',
#      'release_date': '2008-05-06',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5bdpvQ02Fk1x15PXlmSYN3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mF1OinWKYYezIeNfhLrd3'},
#       'href': 'https://api.spotify.com/v1/artists/6mF1OinWKYYezIeNfhLrd3',
#       'id': '6mF1OinWKYYezIeNfhLrd3',
#       'name': 'The Questions',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mF1OinWKYYezIeNfhLrd3'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 133853,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560771864'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2GhDmsnon4gdLDYEZIdBqL'},
#     'href': 'https://api.spotify.com/v1/tracks/2GhDmsnon4gdLDYEZIdBqL',
#     'id': '2GhDmsnon4gdLDYEZIdBqL',
#     'is_local': False,
#     'name': 'Jeopardy',
#     'popularity': 9,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4aa69f3fc51993736c2b5dea999f2c65af77a6fc?cid=5de0c3326eed4e17a4e2b226fc57a68f',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:2GhDmsnon4gdLDYEZIdBqL'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2BS3fywRW33o5GygfzZaOZ'},
#        'href': 'https://api.spotify.com/v1/artists/2BS3fywRW33o5GygfzZaOZ',
#        'id': '2BS3fywRW33o5GygfzZaOZ',
#        'name': 'Wild Pink',
#        'type': 'artist',
#        'uri': 'spotify:artist:2BS3fywRW33o5GygfzZaOZ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4UkBP7ceICNkM9aMR1YKbs'},
#      'href': 'https://api.spotify.com/v1/albums/4UkBP7ceICNkM9aMR1YKbs',
#      'id': '4UkBP7ceICNkM9aMR1YKbs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27335e5938c0ea087e4947b01f8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0235e5938c0ea087e4947b01f8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485135e5938c0ea087e4947b01f8',
#        'width': 64}],
#      'name': '6 Cover Songs',
#      'release_date': '2021-04-16',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:4UkBP7ceICNkM9aMR1YKbs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2BS3fywRW33o5GygfzZaOZ'},
#       'href': 'https://api.spotify.com/v1/artists/2BS3fywRW33o5GygfzZaOZ',
#       'id': '2BS3fywRW33o5GygfzZaOZ',
#       'name': 'Wild Pink',
#       'type': 'artist',
#       'uri': 'spotify:artist:2BS3fywRW33o5GygfzZaOZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 49900,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAUM82100090'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2GFzfnVgIOrvLx0QvLWf1d'},
#     'href': 'https://api.spotify.com/v1/tracks/2GFzfnVgIOrvLx0QvLWf1d',
#     'id': '2GFzfnVgIOrvLx0QvLWf1d',
#     'is_local': False,
#     'name': 'Jeopardy Theme Song',
#     'popularity': 8,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7bd5afc0ce3ed573c2dd53e1755dc69850d64ee7?cid=5de0c3326eed4e17a4e2b226fc57a68f',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2GFzfnVgIOrvLx0QvLWf1d'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0eYAY6QPUpjd9lo7RV9meV'},
#      'href': 'https://api.spotify.com/v1/albums/0eYAY6QPUpjd9lo7RV9meV',
#      'id': '0eYAY6QPUpjd9lo7RV9meV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b49e735892d8021f576ca95c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b49e735892d8021f576ca95c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b49e735892d8021f576ca95c',
#        'width': 64}],
#      'name': 'Awesome Game Show Themes',
#      'release_date': '2014-04-15',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:0eYAY6QPUpjd9lo7RV9meV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25IgBFib2nbTzWL5BEHfOu'},
#       'href': 'https://api.spotify.com/v1/artists/25IgBFib2nbTzWL5BEHfOu',
#       'id': '25IgBFib2nbTzWL5BEHfOu',
#       'name': 'Musosis',
#       'type': 'artist',
#       'uri': 'spotify:artist:25IgBFib2nbTzWL5BEHfOu'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 131274,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6V82398291'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5N1EQPY9q1EKMRUKIDkyrA'},
#     'href': 'https://api.spotify.com/v1/tracks/5N1EQPY9q1EKMRUKIDkyrA',
#     'id': '5N1EQPY9q1EKMRUKIDkyrA',
#     'is_local': False,
#     'name': 'Theme from "Jeopardy"',
#     'popularity': 2,
#     'preview_url': 'https://p.scdn.co/mp3-preview/761ac0b5ebe3335d657ff7a5672ab3086351cc15?cid=5de0c3326eed4e17a4e2b226fc57a68f',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5N1EQPY9q1EKMRUKIDkyrA'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4sxIABfQGN6MnYEkd31EHh'},
#      'href': 'https://api.spotify.com/v1/albums/4sxIABfQGN6MnYEkd31EHh',
#      'id': '4sxIABfQGN6MnYEkd31EHh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736923be58f5993b925fa2f7a5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026923be58f5993b925fa2f7a5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516923be58f5993b925fa2f7a5',
#        'width': 64}],
#      'name': 'International TV Themes Vol.3',
#      'release_date': '2006-02-13',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:4sxIABfQGN6MnYEkd31EHh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40dRlFQkN6KBLpbf1GEvto'},
#       'href': 'https://api.spotify.com/v1/artists/40dRlFQkN6KBLpbf1GEvto',
#       'id': '40dRlFQkN6KBLpbf1GEvto',
#       'name': 'Aron Apping',
#       'type': 'artist',
#       'uri': 'spotify:artist:40dRlFQkN6KBLpbf1GEvto'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
# ...
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:4DJJE7f4bR4euoWVODTXY6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/330BdYPbfBhMcVzpczqal0'},
#       'href': 'https://api.spotify.com/v1/artists/330BdYPbfBhMcVzpczqal0',
#       'id': '330BdYPbfBhMcVzpczqal0',
#       'name': 'Hanz Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:330BdYPbfBhMcVzpczqal0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 29784,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM6MZ1966404'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0d7AeCev3cAvg1kKFf0nO2'},
#     'href': 'https://api.spotify.com/v1/tracks/0d7AeCev3cAvg1kKFf0nO2',
#     'id': '0d7AeCev3cAvg1kKFf0nO2',
#     'is_local': False,
#     'name': '"Jeopardy" - Main Game Show Theme',
#     'popularity': 0,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0d7AeCev3cAvg1kKFf0nO2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SlgdwEE70ZbFLtj6V8tDa'},
#        'href': 'https://api.spotify.com/v1/artists/3SlgdwEE70ZbFLtj6V8tDa',
#        'id': '3SlgdwEE70ZbFLtj6V8tDa',
#        'name': 'Harlequins Enigma',
#        'type': 'artist',
#        'uri': 'spotify:artist:3SlgdwEE70ZbFLtj6V8tDa'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0zpvJQEZa2G0fGw4q13n0i'},
#      'href': 'https://api.spotify.com/v1/albums/0zpvJQEZa2G0fGw4q13n0i',
#      'id': '0zpvJQEZa2G0fGw4q13n0i',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735c096f11da89ce897b8efc16',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025c096f11da89ce897b8efc16',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515c096f11da89ce897b8efc16',
#        'width': 64}],
#      'name': 'Themes, Vol. 1',
#      'release_date': '2015-08-17',
#      'release_date_precision': 'day',
#      'total_tracks': 23,
#      'type': 'album',
#      'uri': 'spotify:album:0zpvJQEZa2G0fGw4q13n0i'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SlgdwEE70ZbFLtj6V8tDa'},
#       'href': 'https://api.spotify.com/v1/artists/3SlgdwEE70ZbFLtj6V8tDa',
#       'id': '3SlgdwEE70ZbFLtj6V8tDa',
#       'name': 'Harlequins Enigma',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SlgdwEE70ZbFLtj6V8tDa'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2XP4UvuJoUxBIjO95l8Mlr'},
#       'href': 'https://api.spotify.com/v1/artists/2XP4UvuJoUxBIjO95l8Mlr',
#       'id': '2XP4UvuJoUxBIjO95l8Mlr',
#       'name': 'Edgar Froese',
#       'type': 'artist',
#       'uri': 'spotify:artist:2XP4UvuJoUxBIjO95l8Mlr'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 138207,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR26V1541799'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2VZ6BMrop5EKyzJwMI0Yrv'},
#     'href': 'https://api.spotify.com/v1/tracks/2VZ6BMrop5EKyzJwMI0Yrv',
#     'id': '2VZ6BMrop5EKyzJwMI0Yrv',
#     'is_local': False,
#     'name': 'Jeopardy',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ddf15f99fa14ea97087941281a6e243ee44a65fa?cid=5de0c3326eed4e17a4e2b226fc57a68f',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:2VZ6BMrop5EKyzJwMI0Yrv'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21VBNkZvKxrI9zmfFRxXvn'},
#        'href': 'https://api.spotify.com/v1/artists/21VBNkZvKxrI9zmfFRxXvn',
#        'id': '21VBNkZvKxrI9zmfFRxXvn',
#        'name': '8-Bit Arcade',
#        'type': 'artist',
#        'uri': 'spotify:artist:21VBNkZvKxrI9zmfFRxXvn'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7FER8zGKAvYJ6NBozrpqXN'},
#      'href': 'https://api.spotify.com/v1/albums/7FER8zGKAvYJ6NBozrpqXN',
#      'id': '7FER8zGKAvYJ6NBozrpqXN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ab9404b3f968102abcaa0098',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ab9404b3f968102abcaa0098',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ab9404b3f968102abcaa0098',
#        'width': 64}],
#      'name': '101 Television Themes, Vol. 1',
#      'release_date': '2018-04-08',
#      'release_date_precision': 'day',
#      'total_tracks': 101,
#      'type': 'album',
#      'uri': 'spotify:album:7FER8zGKAvYJ6NBozrpqXN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21VBNkZvKxrI9zmfFRxXvn'},
#       'href': 'https://api.spotify.com/v1/artists/21VBNkZvKxrI9zmfFRxXvn',
#       'id': '21VBNkZvKxrI9zmfFRxXvn',
#       'name': '8-Bit Arcade',
#       'type': 'artist',
#       'uri': 'spotify:artist:21VBNkZvKxrI9zmfFRxXvn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 59999,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUXN21803532'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0o3fK4kYPsnlS5e3GpazC3'},
#     'href': 'https://api.spotify.com/v1/tracks/0o3fK4kYPsnlS5e3GpazC3',
#     'id': '0o3fK4kYPsnlS5e3GpazC3',
#     'is_local': False,
#     'name': 'Jeopardy (Main Theme) - Computer Game Version',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1d3c350c2daf480fe74b520dee5fc026aa08fb8d?cid=5de0c3326eed4e17a4e2b226fc57a68f',
#     'track_number': 43,
#     'type': 'track',
#     'uri': 'spotify:track:0o3fK4kYPsnlS5e3GpazC3'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Jeopardy+Theme&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 84}}

# %%
def appendToUserQueue(track_uri):
  spotify_user.generic_post('https://api.spotify.com/v1/me/player/queue' + '?uri=' + track_uri)

# %%
def getUserCurrentTrack():
  return spotify_user.generic_get('https://api.spotify.com/v1/me/player/currently-playing')['item']

# %%
def getUserCurrentTrackProgress():
  return spotify_user.generic_get('https://api.spotify.com/v1/me/player/currently-playing')['progress_ms']

# %%
def skipToNextTrack():
  spotify_user.generic_post('https://api.spotify.com/v1/me/player/next')

# %%
def playTrack(track_uri, pos = 0):
  track_json = {}
  track_json['uris'] = [track_uri]
  track_json['position_ms'] = pos
  spotify_user.generic_put('https://api.spotify.com/v1/me/player/play', data = track_json)

# %%
def addAudioFeatures(track_list):
  track_id_string = ''
  for track in track_list:
    track_id_string = track_id_string + track['id'] + ','
  track_id_string = track_id_string[:-1] #remove last character of string, as an extra comma was added
  features = spotify.generic_get('https://api.spotify.com/v1/audio-features?ids=' + track_id_string)['audio_features']
  for i in range(len(track_list)):
    track_list[i]['danceability'] = features[i]['danceability']
    track_list[i]['energy'] = features[i]['energy']
    track_list[i]['key'] = features[i]['key']
    track_list[i]['loudness'] = features[i]['loudness']
    track_list[i]['mode'] = features[i]['mode']
    track_list[i]['speechiness'] = features[i]['speechiness']
    track_list[i]['acousticness'] = features[i]['acousticness']
    track_list[i]['instrumentalness'] = features[i]['instrumentalness']
    track_list[i]['liveness'] = features[i]['liveness']
    track_list[i]['valence'] = features[i]['valence']
    track_list[i]['tempo'] = features[i]['tempo']
    track_list[i]['time_signature'] = features[i]['time_signature']

  return track_list

# %%
def sortTracksByFeatures(track_list, feature = 'energy', ascending=True):
  def getFeature(track):
    return track[feature]

  # sort list with key
  track_list.sort(key=getFeature, reverse= not ascending)

# %%
def sweepVolumeDown(speed = 10):
  for volume in range(0, 101, speed):
    spotify_user.generic_put('https://api.spotify.com/v1/me/player/volume?volume_percent=' + str(100 - volume))

# %%
def sweepVolumeUp(speed = 10):
  for volume in range(0, 101, speed):
    spotify_user.generic_put('https://api.spotify.com/v1/me/player/volume?volume_percent=' + str(volume))

# %%
#To get the user's queue, we;
#1 - add a song with a known ID (in this case, the jeopardy wait song) to the end of the queue (we could possibly make this the users currently playing song, but what if they have this song in the queue?)
#2 - skip songs until we get to our known ID, adding the ID of each song in the queue to a list
#3 - return the list of tracks 

#Current implementation seems to work, but does is not efficient, need to find a way to wait until posts are complete to do gets
def getUserQueue():
  user_queue = []
  appendToUserQueue('spotify:track:7GyGUC8QFMS9NoHJsgNqh1') #1
  time.sleep(1)
  skipToNextTrack()
  time.sleep(1)
  current_track = getUserCurrentTrack()
  time.sleep(1)
  while current_track['id'] != '7GyGUC8QFMS9NoHJsgNqh1': #2
    user_queue.append(current_track)
    skipToNextTrack()
    time.sleep(1)
    current_track = getUserCurrentTrack()
    time.sleep(1)


  return user_queue #3

# %%
#To sort a user's queue, we:
#1 - get the users currently playing track and the time in the track at which we are beginning this
#2 - get the items currently in the User's Queue
#3 - return the user's playback to what they were listening to while we sort their queue
#4 - sort their queue by passed values
#5 - add tracks back to queue in sorted order
def sortUserQueue(feature = 'energy', ascending = True):
  #sweepVolumeDown()
  current_track = getUserCurrentTrack() #1
  progress = getUserCurrentTrackProgress()
  user_queue = getUserQueue() #2
  playTrack(current_track['uri'], pos = progress) #3
  #sweepVolumeUp()
  user_queue_plus_features = addAudioFeatures(user_queue) #4
  sortTracksByFeatures(user_queue_plus_features, feature, ascending)
  for track in user_queue_plus_features: #5
    appendToUserQueue(track['uri'])

# %%
sortUserQueue()

# %%
queue = getUserQueue()
for track in queue:
  print(track['name'])
# Out:
# Ohio Is For Lovers - Lo-Fi
# Circadian Deity
# Friends Suck
# Hosnian Prime
# God Damn
# Violet
# Greyblood

# %%
for track in queue:
  print(track['name'])
